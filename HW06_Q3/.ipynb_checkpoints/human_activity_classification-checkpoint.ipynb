# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# فعالیت‌بدنی‌بندی</font>
# </h1>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# مجموعه‌داده‌های <b>تشخیص فعالیت انسانی (HAR)</b> مجموعه‌ای از داده‌های حسگر هستند که هدف آنها دسته‌بندی و شناسایی فعالیت‌های مختلف انسانی بر اساس الگوهای موجود در خوانش‌های حسگر است. در تحقیقات یادگیری ماشین و داده‌کاوی از این مجموعه‌داده‌ها برای توسعه‌ی الگوریتم‌ها و مدل‌های سیستم‌های تشخیص فعالیت استفاده می‌شوند. ویژگی‌های مجموعه‌داده‌های HAR معمولاً برگرفته از داده‌های حسگرهای مختلف مانند شتاب‌سنج، ژیروسکوپ و مغناطیس‌سنج است. این سنسورها معمولاً در گوشی‌های هوشمند، ساعت‌های هوشمند و دستگاه‌های پوشیدنی یافت می‌شوند. حسگرها داده‌های مربوط به حرکت و جهت‌گیری دستگاه و همچنین محیط اطراف را ثبت می‌کنند. در صورت علاقه، می‌توانید نمونه‌ای از ثبت این داده‌ها را در <a href="https://www.youtube.com/watch?v=XOEN9W05_4A">این ویدیو</a> مشاهده کنید. این اندازه‌گیری‌ها در فواصل زمانی منظم گرفته می‌شوند و به‌عنوان داده‌های سری زمانی نشان داده می‌شوند. هدف مجموعه‌داده‌های HAR شناسایی و دسته‌بندی دقیق فعالیت‌های انسانی خاص است. این فعالیت‌ها می توانند بسته به کاربرد یا زمینه‌ی مورد مطالعه متفاوت باشند. نمونه‌هایی از فعالیت‌های رایج شناخته‌شده عبارتند از راه رفتن، دویدن، ایستادن، نشستن، بالا رفتن از پله‌ها و فعالیت‌های مرتبط با ورزش یا تناسب اندام. هدف، ساخت مدل‌های پیش‌بینی‌کننده است تا بتوانند به‌طور خودکار این فعالیت‌ها را بر اساس الگوهای آشکار یا پنهان موجود در داده‌های حسگر تشخیص دهند و بین‌شان تمایز قائل شوند.
# <br>
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir">مجموعه‌داده</font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در مجموعه‌داده‌ای که در اختیار شما قرار گرفته به‌ازای هر داده‌ای که ثبت شده نوع فعالیت آن در ستون <code>Activity_Name</code> نوشته شده است. انواع فعالیت موجود در این مجموعه‌داده عبارتند از:
#
# </font>
# </p>
#
# <center>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# | مقدار | نوع فعالیت |
# | :---: | :---: |
# | Walking | راه رفتن |
# | Walking_Upstairs | بالا رفتن از پله‌ها |
# | Walking_Downstairs | پایین رفتن از پله‌ها |
# | Sitting | نشستن |
# | Standing | ایستادن |
# | Laying | خوابیدن |
#
# </font>
# </p>
# </center>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در ابتدا مجموعه‌داده‌های آموزش (<code>train</code>) و آزمون (<code>test</code>) از فایل‌های موجود در پوشه بخوانید. البته نیازی به ستون <code>subject</code> نیست. در صورت تمایل می‌توانید بخشی از مجموعه‌ی آموزشی را جدا کرده و برای اعتبارسنجی (<code>validation</code>) استفاده کنید.
#     </font>
# </p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
print(train.shape)
print(test.shape)
# Out:
# (7352, 563)
# (2947, 561)

# %%
train.head(5)
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.923527         -0.934724  ...                        -0.710304
# 1         -0.957686         -0.943068  ...                        -0.861499
# 2         -0.977469         -0.938692  ...                        -0.760104
# 3         -0.989302         -0.938692  ...                        -0.482845
# 4         -0.990441         -0.942469  ...                        -0.699205
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                    -0.112754                              0.030400
# 1                     0.053477                             -0.007435
# 2                    -0.118559                              0.177899
# 3                    -0.036788                             -0.012892
# 4                     0.123320                              0.122542
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                         -0.464761                             -0.018446
# 1                         -0.732626                              0.703511
# 2                          0.100699                              0.808529
# 3                          0.640011                             -0.485366
# 4                          0.693578                             -0.615971
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  Subject  \
# 0             -0.841247              0.179941             -0.058627        1
# 1             -0.844788              0.180289             -0.054317        1
# 2             -0.848933              0.180637             -0.049118        1
# 3             -0.848649              0.181935             -0.047663        1
# 4             -0.847865              0.185151             -0.043892        1
#
#    Activity_Name
# 0       Standing
# 1       Standing
# 2       Standing
# 3       Standing
# 4       Standing
#
# [5 rows x 563 columns]

# %%
test.head(5)
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.283669          -0.015857          -0.059881         -0.973736
# 1           0.322557          -0.039917          -0.082557         -0.355588
# 2           0.294853          -0.010700          -0.100636         -0.980507
# 3           0.285264          -0.015595          -0.150264         -0.236935
# 4           0.311611          -0.015282          -0.109654         -0.932390
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.899287         -0.782522         -0.976986         -0.894329
# 1         -0.337817         -0.265232         -0.397431         -0.341815
# 2         -0.895418         -0.963306         -0.980855         -0.884619
# 3          0.523830         -0.378750         -0.297927          0.478829
# 4         -0.983798         -0.971810         -0.926542         -0.981748
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
# 0         -0.785570         -0.895825  ...                         0.223438
# 1         -0.276091         -0.073071  ...                         0.427286
# 2         -0.964184         -0.927680  ...                         0.337037
# 3         -0.384961          0.133768  ...                         0.361520
# 4         -0.969975         -0.888423  ...                         0.191532
#
#    fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                        -0.252492                        -0.658040
# 1                        -0.433622                        -0.781109
# 2                        -0.439849                        -0.723350
# 3                         0.805276                         0.721432
# 4                         0.049477                        -0.254858
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.003614                              0.096807
# 1                    -0.375235                             -0.345779
# 2                    -0.392573                              0.320364
# 3                    -0.042795                              0.299331
# 4                    -0.022340                              0.000328
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.451286                              0.493474
# 1                          0.428791                             -0.359078
# 2                          0.554949                             -0.501292
# 3                          0.584471                              0.817918
# 4                         -0.173259                             -0.466109
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)
# 0             -0.852602              0.188326              0.067392
# 1             -0.664690              0.265582              0.181672
# 2             -0.857665              0.188949             -0.021815
# 3             -0.711628              0.297052              0.006109
# 4              0.592952             -0.416970             -0.593468
#
# [5 rows x 561 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir">تحلیل اکتشافی داده</font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در ابتدا پیشنهاد می‌کنیم کمی به بررسی دقیق‌تر و آماری داده‌هایی که در دسترس‌تان است بپردازید و در صورت علاقه نمودارهایی را جهت بررسی توزیع‌های داده رسم کنید.
# <span style="color:orange">(اختیاری)</span>
# </font>
# </p>

# %%
# To-Do (Exploratory Data Analysis)
for i in range(10) :
    plt.scatter(train[train.columns[2*i]] , train[train.columns[2*i+1]] , c = train[train.columns[-2]])
    plt.xlabel(train.columns[2*i])
    plt.ylabel(train.columns[2*i+1])
    plt.show()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity_Name
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
train = train.drop_duplicates()
train = train.dropna()
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity_Name
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train['Activity'] = le.fit_transform(train['Activity_Name'])

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir">مهندسی ویژگی</font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# طبق بررسی‌هایی که از داده‌ها داشته‌اید یا جهت دست‌یابی به عملکرد بهتر در مدل‌های پیش‌بینی‌کننده‌ی خود ممکن است به مهندسی ویژگی‌‌ها (کدگذاری متغیر هدف،‌ حذف ویژگی‌ها، تغییر نوع ویژگی‌ها، ساخت ویژگی جدید، تغییر مقیاس و غیره) نیاز داشته باشید. در این‌صورت می‌توانید در این قسمت از هر روش یا ابزاری که مناسب می‌دانید به‌منظور مهندسی ویژگی‌ها استفاده کنید.
# </font>
# </p>

# %%
# To-Do (Feature Engineering)
import seaborn as sns
cr = train.corr()['Activity']
cr = dict(cr)
cr = sorted(cr.items() , key = lambda x:x[1] , reverse=True)
# Out:
# <ipython-input-10-c8e9c41a78ac>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cr = train.corr()['Activity']

# %%
cr
# Out:
# [('Activity', 1.0),
#  ('fBodyAccJerk-entropy()-X', 0.845190074921194),
#  ('tBodyGyroJerk-entropy()-Z', 0.8447539135776349),
#  ('tBodyAccJerk-entropy()-Y', 0.8370341345764243),
#  ('tBodyAcc-sma()', 0.8356206978272067),
#  ('tBodyAccJerkMag-entropy()', 0.8353763655626184),
#  ('tBodyAccMag-mean()', 0.8331260484826197),
#  ('tBodyAccMag-sma()', 0.8331260484826197),
#  ('tGravityAccMag-mean()', 0.8331260484826197),
#  ('tGravityAccMag-sma()', 0.8331260484826197),
#  ('fBodyAccJerk-entropy()-Y', 0.8322837870347648),
#  ('fBodyAccMag-entropy()', 0.8312215155559377),
#  ('fBodyAcc-entropy()-Y', 0.83111392682001),
#  ('fBodyAcc-std()-Y', 0.830051758061492),
#  ('fBodyBodyAccJerkMag-entropy()', 0.8292596792499202),
#  ('tBodyGyroMag-mean()', 0.8276382153140024),
#  ('tBodyGyroMag-sma()', 0.8276382153140024),
#  ('tBodyGyro-sma()', 0.8274519044775637),
#  ('tBodyAccJerk-entropy()-X', 0.8268422171213519),
#  ('tBodyAcc-mad()-Y', 0.8259991522525835),
#  ('fBodyAcc-entropy()-X', 0.8256630174109374),
#  ('tBodyAcc-std()-Y', 0.825453023995777),
#  ('fBodyGyro-entropy()-Z', 0.819918451256834),
#  ('tBodyAccJerk-entropy()-Z', 0.8197058600291951),
#  ('tBodyAcc-max()-X', 0.819678692426395),
#  ('fBodyAcc-mad()-Y', 0.818680354902606),
#  ('fBodyAcc-sma()', 0.8164054423611011),
#  ('tBodyAcc-std()-X', 0.8155826758134209),
#  ('fBodyAcc-std()-X', 0.8151592207272444),
#  ('fBodyGyro-entropy()-X', 0.814364008905139),
#  ('tBodyGyroJerk-entropy()-X', 0.8141278029089937),
#  ('tBodyAcc-iqr()-Y', 0.8133267712112048),
#  ('fBodyAcc-entropy()-Z', 0.812753807703771),
#  ('fBodyAcc-mad()-X', 0.8117046750453681),
#  ('fBodyAcc-max()-Y', 0.8109780604832638),
#  ('tBodyGyroJerkMag-entropy()', 0.8079167275018323),
#  ('fBodyAccJerk-entropy()-Z', 0.8079146957407233),
#  ('fBodyGyro-mad()-Z', 0.8067765170348723),
#  ('tBodyAccMag-max()', 0.8063157051499903),
#  ('tGravityAccMag-max()', 0.8063157051499903),
#  ('tBodyAcc-mad()-X', 0.8061115232315973),
#  ('tBodyGyro-std()-Z', 0.8058919866277502),
#  ('tBodyAcc-mad()-Z', 0.8055684180998018),
#  ('fBodyAcc-mean()-Y', 0.8053200146095123),
#  ('tBodyGyro-mad()-Z', 0.8051382832352462),
#  ('fBodyAcc-mean()-X', 0.8044102570752073),
#  ('fBodyAcc-std()-Z', 0.8029433543501827),
#  ('tBodyAcc-std()-Z', 0.8019999626213468),
#  ('fBodyAccMag-mad()', 0.8019400779416673),
#  ('tBodyAccMag-entropy()', 0.8017456493072802),
#  ('tGravityAccMag-entropy()', 0.8017456493072802),
#  ('fBodyBodyGyroJerkMag-entropy()', 0.8013326456642911),
#  ('tBodyAcc-iqr()-Z', 0.8007342370151708),
#  ('fBodyAcc-max()-X', 0.7999660442495807),
#  ('fBodyBodyGyroMag-entropy()', 0.7993921089453371),
#  ('fBodyGyro-std()-Z', 0.7993704155924569),
#  ('fBodyGyro-entropy()-Y', 0.7965845026627727),
#  ('fBodyGyro-mean()-Z', 0.7961404734932769),
#  ('tBodyAcc-max()-Y', 0.7952852386079718),
#  ('fBodyAcc-mad()-Z', 0.7933943114604886),
#  ('fBodyBodyGyroMag-mad()', 0.7911395393218141),
#  ('tBodyAccMag-std()', 0.7906015641716563),
#  ('tGravityAccMag-std()', 0.7906015641716563),
#  ('fBodyGyro-sma()', 0.790450305237881),
#  ('fBodyAccMag-mean()', 0.7888191542789581),
#  ('fBodyAccMag-sma()', 0.7888191542789581),
#  ('tBodyGyro-iqr()-Z', 0.7885311569582241),
#  ('tBodyAccMag-mad()', 0.7859749152017926),
#  ('tGravityAccMag-mad()', 0.7859749152017926),
#  ('fBodyAccMag-std()', 0.78580812879819),
#  ('tBodyAccJerk-mad()-X', 0.7854047708362707),
#  ('tBodyGyroMag-mad()', 0.7848179098733203),
#  ('fBodyGyro-mad()-X', 0.783770481881722),
#  ('fBodyAccMag-iqr()', 0.7834859958584932),
#  ('tBodyAccJerk-std()-X', 0.7834320448979359),
#  ('tBodyGyroJerk-entropy()-Y', 0.7833961968294877),
#  ('tBodyAccJerk-iqr()-X', 0.7829940468142954),
#  ('fBodyAccJerk-mean()-X', 0.7821677002970479),
#  ('fBodyAccJerk-std()-X', 0.7804206500256754),
#  ('fBodyAccJerk-mad()-X', 0.7803288399706847),
#  ('tBodyGyro-std()-X', 0.7798537784679295),
#  ('tBodyGyroMag-std()', 0.7797447468972306),
#  ('fBodyBodyGyroMag-std()', 0.7796470359741056),
#  ('tBodyGyroMag-iqr()', 0.778563723747144),
#  ('fBodyAcc-bandsEnergy()-1,8.1', 0.7783007031676381),
#  ('tBodyAccJerkMag-mean()', 0.7777138693590252),
#  ('tBodyAccJerkMag-sma()', 0.7777138693590252),
#  ('fBodyGyro-mean()-X', 0.7775008871618112),
#  ('tBodyGyro-mad()-X', 0.7770200774148106),
#  ('tBodyAcc-iqr()-X', 0.7760927402771557),
#  ('tBodyAccJerk-sma()', 0.7755908188331436),
#  ('tBodyGyroMag-max()', 0.7752820335921894),
#  ('fBodyAccJerk-sma()', 0.773276159211644),
#  ('fBodyGyro-std()-X', 0.7727992660698016),
#  ('fBodyAcc-mean()-Z', 0.7706836258276387),
#  ('fBodyAcc-max()-Z', 0.7700390904148819),
#  ('fBodyAcc-iqr()-X', 0.7697585732532367),
#  ('tBodyAccJerk-iqr()-Y', 0.7692598408044661),
#  ('tBodyAcc-max()-Z', 0.7688829948168283),
#  ('fBodyBodyAccJerkMag-mean()', 0.7680399010919434),
#  ('fBodyBodyAccJerkMag-sma()', 0.7680399010919434),
#  ('fBodyAccJerk-iqr()-X', 0.7674637564123478),
#  ('tBodyAccJerk-mad()-Y', 0.7671460461917804),
#  ('tBodyAccMag-iqr()', 0.7671130095948281),
#  ('tGravityAccMag-iqr()', 0.7671130095948281),
#  ('fBodyAccJerk-mean()-Y', 0.7670764868856387),
#  ('fBodyBodyAccJerkMag-iqr()', 0.7670119202780351),
#  ('fBodyAccJerk-max()-X', 0.7663029713404921),
#  ('tBodyAccJerkMag-max()', 0.7654560601496175),
#  ('tBodyGyro-iqr()-Y', 0.7640436752910835),
#  ('tBodyGyro-mad()-Y', 0.7626841625252935),
#  ('tBodyAcc-entropy()-Y', 0.7609021829825713),
#  ('tBodyGyro-iqr()-X', 0.7599056890035515),
#  ('fBodyAccJerk-iqr()-Y', 0.7598438158855304),
#  ('tBodyAccJerkMag-std()', 0.7597773415973194),
#  ('fBodyAcc-iqr()-Y', 0.7592517229719399),
#  ('tBodyAccJerk-std()-Y', 0.7591810025911896),
#  ('fBodyAcc-bandsEnergy()-1,16.1', 0.758898666392616),
#  ('fBodyBodyAccJerkMag-mad()', 0.7588934513389297),
#  ('fBodyGyro-max()-Z', 0.7581756356906769),
#  ('fBodyAccJerk-mad()-Y', 0.7570107818083935),
#  ('tBodyAccJerkMag-mad()', 0.7560127191671233),
#  ('fBodyAcc-bandsEnergy()-1,24.1', 0.7546351526544511),
#  ('tBodyGyro-std()-Y', 0.754447195849221),
#  ('fBodyBodyGyroMag-mean()', 0.7541675331516176),
#  ('fBodyBodyGyroMag-sma()', 0.7541675331516176),
#  ('fBodyAcc-energy()-Y', 0.7531301098697715),
#  ('tBodyGyro-max()-Z', 0.7529684025886643),
#  ('fBodyGyro-std()-Y', 0.7528468993961314),
#  ('tBodyGyro-max()-X', 0.7520985491340563),
#  ('tBodyAccMag-energy()', 0.7515247644358288),
#  ('tGravityAccMag-energy()', 0.7515247644358288),
#  ('fBodyAccJerk-std()-Y', 0.7463710846969775),
#  ('tBodyGyroJerk-iqr()-Z', 0.7461904007856751),
#  ('tBodyAccJerkMag-iqr()', 0.745990839416279),
#  ('fBodyBodyGyroMag-iqr()', 0.7454786755846164),
#  ('fBodyGyro-iqr()-Z', 0.7448976018234448),
#  ('fBodyAccMag-max()', 0.743228529575899),
#  ('fBodyGyro-max()-X', 0.7413506791901197),
#  ('tBodyGyroJerk-mad()-Z', 0.741203306407178),
#  ('fBodyBodyAccJerkMag-std()', 0.739870781257024),
#  ('fBodyBodyGyroMag-max()', 0.7396873973218822),
#  ('fBodyGyro-mad()-Y', 0.7391433331949981),
#  ('tBodyGyroJerk-std()-Z', 0.7325841716885035),
#  ('tBodyAccJerk-max()-X', 0.7303360064133576),
#  ('tBodyGyroJerk-iqr()-X', 0.728738630436796),
#  ('fBodyGyro-mean()-Y', 0.7284886461447027),
#  ('fBodyAccJerk-bandsEnergy()-1,8.1', 0.7265868823092997),
#  ('fBodyGyro-iqr()-X', 0.7261986528851673),
#  ('angle(Y,gravityMean)', 0.7254082806693745),
#  ('tBodyGyroJerk-mad()-X', 0.7232568141460971),
#  ('fBodyGyro-max()-Y', 0.7217674842242585),
#  ('tBodyGyroMag-energy()', 0.721444917289315),
#  ('tBodyGyroJerk-sma()', 0.7205833982334741),
#  ('tBodyGyroJerk-std()-X', 0.7172728095732949),
#  ('tBodyGyroJerkMag-mean()', 0.7140102493024904),
#  ('tBodyGyroJerkMag-sma()', 0.7140102493024904),
#  ('fBodyAccJerk-max()-Y', 0.7137450123851246),
#  ('tBodyAccJerk-max()-Y', 0.7135551807515562),
#  ('fBodyBodyAccJerkMag-max()', 0.7077027294722799),
#  ('tBodyAccJerk-iqr()-Z', 0.7048540489254964),
#  ('tBodyGyroJerk-max()-Z', 0.7043067486459487),
#  ('tBodyAccJerkMag-min()', 0.7042020442830612),
#  ('fBodyAccJerk-mean()-Z', 0.701154203200571),
#  ('tBodyAccJerk-mad()-Z', 0.7000962339645747),
#  ('fBodyAcc-iqr()-Z', 0.7000293738065073),
#  ('tBodyAcc-entropy()-X', 0.6988891124552336),
#  ('tBodyGyroJerk-max()-X', 0.6986683455944154),
#  ('tBodyAcc-entropy()-Z', 0.6953271005780078),
#  ('tBodyAccJerk-std()-Z', 0.6931609583839149),
#  ('fBodyAcc-energy()-X', 0.6918396795216767),
#  ('fBodyAcc-bandsEnergy()-1,24', 0.6917149536770716),
#  ('tBodyAccMag-min()', 0.6913490381247077),
#  ('tGravityAccMag-min()', 0.6913490381247077),
#  ('tBodyGyroMag-min()', 0.6904933789904472),
#  ('fBodyAccJerk-iqr()-Z', 0.6900740381587479),
#  ('tBodyAcc-energy()-Y', 0.6897998009536686),
#  ('tBodyAcc-energy()-X', 0.6897245376781624),
#  ('fBodyAccJerk-mad()-Z', 0.6890529384910445),
#  ('tBodyGyro-max()-Y', 0.688091027688252),
#  ('fBodyAcc-bandsEnergy()-1,16', 0.687678491136961),
#  ('fBodyAcc-bandsEnergy()-1,8', 0.6825458114546145),
#  ('fBodyAccJerk-std()-Z', 0.6792372848977511),
#  ('tBodyGyroJerkMag-min()', 0.6791172288135339),
#  ('tBodyGyroJerkMag-iqr()', 0.6734041596979276),
#  ('fBodyAcc-bandsEnergy()-1,24.2', 0.6729132790366825),
#  ('fBodyAcc-bandsEnergy()-1,16.2', 0.6726069538400848),
#  ('fBodyAcc-energy()-Z', 0.6719250184898525),
#  ('tBodyGyro-energy()-X', 0.6701858506652462),
#  ('fBodyAccMag-energy()', 0.6687570577934181),
#  ('fBodyGyro-iqr()-Y', 0.6685771929682918),
#  ('tBodyGyro-arCoeff()-Z,2', 0.6617154974765933),
#  ('fBodyAcc-bandsEnergy()-1,8.2', 0.6604924854188434),
#  ('fBodyBodyGyroJerkMag-mean()', 0.6597385748820694),
#  ('fBodyBodyGyroJerkMag-sma()', 0.6597385748820694),
#  ('fBodyGyro-bandsEnergy()-49,64.1', 0.36837551947275815),
#  ('fBodyGyro-bandsEnergy()-49,64', 0.3616283473275534),
#  ('fBodyAcc-bandsEnergy()-57,64', 0.35942406196860455),
#  ('tGravityAcc-entropy()-X', 0.3533340400827388),
#  ('fBodyGyro-bandsEnergy()-33,48.1', 0.34844996193877426),
#  ('fBodyAccJerk-skewness()-Z', 0.3484261752125267),
#  ('fBodyBodyAccJerkMag-kurtosis()', 0.3469094123611196),
#  ('tBodyGyro-correlation()-Y,Z', 0.3435820853464427),
#  ('tBodyAccMag-arCoeff()4', 0.3316792388111635),
#  ('tGravityAccMag-arCoeff()4', 0.3316792388111635),
#  ('tBodyGyroJerk-arCoeff()-X,2', 0.3314795476836833),
#  ('fBodyGyro-bandsEnergy()-25,48.1', 0.328301952104413),
#  ('fBodyGyro-bandsEnergy()-33,40.1', 0.32358549848064505),
#  ('fBodyGyro-bandsEnergy()-57,64.2', 0.3178730852665109),
#  ('fBodyGyro-bandsEnergy()-25,32.1', 0.31126140266731417),
#  ('tBodyAccJerk-correlation()-Y,Z', 0.3101241028730263),
#  ('fBodyGyro-bandsEnergy()-57,64', 0.30940128433044634),
#  ('fBodyAcc-bandsEnergy()-57,64.1', 0.3075554051671496),
#  ('fBodyAcc-bandsEnergy()-57,64.2', 0.3035872389593257),
#  ('fBodyGyro-bandsEnergy()-57,64.1', 0.2951906020459563),
#  ('tBodyGyroJerkMag-arCoeff()2', 0.29245515057482996),
#  ('fBodyGyro-bandsEnergy()-17,32.1', 0.29195560114698277),
#  ('tBodyAcc-arCoeff()-X,4', 0.2852882514069945),
#  ('fBodyAccJerk-kurtosis()-Y', 0.2696131324559734),
#  ('fBodyGyro-bandsEnergy()-17,24.1', 0.2680342102819758),
#  ('fBodyAccJerk-bandsEnergy()-57,64.1', 0.2660891638191464),
#  ('fBodyAccJerk-bandsEnergy()-57,64', 0.2645312299943357),
#  ('fBodyBodyGyroMag-maxInds', 0.25898713357365505),
#  ('fBodyAccJerk-bandsEnergy()-57,64.2', 0.24868213703241399),
#  ('fBodyAccJerk-kurtosis()-Z', 0.245215845007712),
#  ('tBodyGyroJerk-arCoeff()-Y,2', 0.24478763422035818),
#  ('tBodyAcc-correlation()-Y,Z', 0.24267459467162103),
#  ('tBodyGyroJerk-correlation()-X,Y', 0.24046462942644406),
#  ('tGravityAcc-arCoeff()-Z,4', 0.23642330031707798),
#  ('tBodyGyro-arCoeff()-Z,4', 0.23310357809366677),
#  ('tGravityAcc-correlation()-X,Z', 0.21777271597654063),
#  ('tGravityAcc-arCoeff()-Y,4', 0.2146261862553585),
#  ('fBodyAcc-skewness()-X', 0.2048783070123652),
#  ('tGravityAcc-arCoeff()-X,2', 0.2014464621905052),
#  ('fBodyGyro-maxInds-Y', 0.1955416194738858),
#  ('tGravityAcc-correlation()-X,Y', 0.18908793912833682),
#  ('tBodyAccJerk-arCoeff()-Y,2', 0.18086140733144845),
#  ('fBodyGyro-maxInds-Z', 0.1751432087259429),
#  ('tBodyGyro-arCoeff()-Y,4', 0.1622960615427901),
#  ('tBodyAcc-arCoeff()-Z,4', 0.16093007867435424),
#  ('tGravityAcc-arCoeff()-Z,2', 0.15027045885241946),
#  ('tGravityAcc-std()-Z', 0.14010558223933922),
#  ('tGravityAcc-mad()-Z', 0.138239723748452),
#  ('fBodyAcc-kurtosis()-X', 0.137393994605264),
#  ('tGravityAcc-iqr()-Z', 0.13352176973639712),
#  ('tGravityAcc-correlation()-Y,Z', 0.12654124464295874),
#  ('fBodyAcc-maxInds-Z', 0.11926293364276563),
#  ('tGravityAcc-iqr()-Y', 0.11376376326393496),
#  ('tGravityAcc-mad()-Y', 0.11265523604807325),
#  ('tGravityAcc-std()-Y', 0.11213109208733955),
#  ('tBodyAccJerk-arCoeff()-Z,2', 0.10507846027776689),
#  ('fBodyAcc-maxInds-Y', 0.10093338418489124),
#  ('tBodyGyroMag-arCoeff()2', 0.10022758599098816),
#  ('tBodyGyro-correlation()-X,Y', 0.09556017167489592),
#  ('fBodyBodyGyroJerkMag-maxInds', 0.09408942084663408),
#  ('tBodyAccJerkMag-arCoeff()4', 0.08870549056360212),
#  ('fBodyBodyGyroJerkMag-skewness()', 0.07924112399954367),
#  ('tGravityAcc-arCoeff()-Y,2', 0.07620485088392366),
#  ('fBodyGyro-skewness()-X', 0.07582894495206702),
#  ('fBodyAcc-skewness()-Z', 0.06031639245335824),
#  ('fBodyBodyGyroJerkMag-kurtosis()', 0.05695122758241427),
#  ('fBodyAcc-maxInds-X', 0.042817566859057875),
#  ('fBodyGyro-kurtosis()-X', 0.039679687654994626),
#  ('tBodyGyroMag-arCoeff()4', 0.038072981208323635),
#  ('tGravityAcc-iqr()-X', 0.0322064898679788),
#  ('tBodyAcc-correlation()-X,Z', 0.029785186444147214),
#  ('tGravityAcc-mad()-X', 0.029167305477071297),
#  ('tGravityAcc-std()-X', 0.028656280516988524),
#  ('fBodyGyro-skewness()-Z', 0.022612215373332488),
#  ('tBodyGyroJerk-mean()-Z', 0.022246711898703093),
#  ('tBodyGyro-mean()-X', 0.016194311056056804),
#  ('fBodyBodyGyroMag-meanFreq()', 0.014614962157497817),
#  ('tBodyAccJerk-arCoeff()-X,2', 0.012782197982836975),
#  ('tBodyGyro-mean()-Y', 0.011108914232598247),
#  ('tBodyAcc-mean()-X', 0.005688666968528338),
#  ('tBodyAccJerk-mean()-X', 0.004918965340407483),
#  ('tBodyGyroJerkMag-arCoeff()4', 0.0024522970481822897),
#  ('angle(tBodyGyroJerkMean,gravityMean)', 0.00124151515210806),
#  ('tBodyGyroJerk-mean()-X', -0.00011164546074851645),
#  ('fBodyAcc-kurtosis()-Z', -0.0011832029722527492),
#  ('fBodyGyro-kurtosis()-Z', -0.0017065765532873532),
#  ('tBodyAccJerk-mean()-Y', -0.0023817113779299307),
#  ('tBodyGyroJerk-correlation()-Y,Z', -0.00448873420631436),
#  ('tBodyAccJerk-mean()-Z', -0.005869588994124423),
#  ('angle(tBodyAccMean,gravity)', -0.0068933486919310035),
#  ('tGravityAcc-arCoeff()-Y,1', -0.01322858473590633),
#  ('tBodyAcc-arCoeff()-Y,4', -0.014589243415882093),
#  ('tBodyGyroJerk-mean()-Y', -0.01723450944574491),
#  ('angle(tBodyAccJerkMean),gravityMean)', -0.018931011406080608),
#  ('angle(tBodyGyroMean,gravityMean)', -0.029547886078923155),
#  ('tBodyGyroJerk-arCoeff()-Y,4', -0.03496979219602742),
#  ('tBodyGyroJerk-arCoeff()-X,4', -0.03796241534468551),
#  ('fBodyBodyAccJerkMag-maxInds', -0.042474953916172),
#  ('fBodyGyro-meanFreq()-Y', -0.04607087567820142),
#  ('Subject', -0.04800120383833464),
#  ('tBodyAcc-mean()-Z', -0.05452371983129108),
#  ('tBodyGyroMag-arCoeff()3', -0.062022338012409875),
#  ('tBodyAcc-mean()-Y', -0.0623102829420278),
#  ('fBodyGyro-kurtosis()-Y', -0.06910751505179326),
#  ('fBodyGyro-skewness()-Y', -0.07406420143571364),
#  ('tBodyGyroJerkMag-arCoeff()3', -0.07558568554673538),
#  ('tBodyAccJerkMag-arCoeff()3', -0.08432381971878654),
#  ('fBodyGyro-maxInds-X', -0.09257833644379279),
#  ('tBodyGyroMag-arCoeff()1', -0.09833837864850742),
#  ('tGravityAcc-entropy()-Z', -0.10549066134912166),
#  ('tGravityAcc-arCoeff()-Z,1', -0.1068676100181577),
#  ('tGravityAcc-arCoeff()-X,1', -0.10845593881660581),
#  ('fBodyBodyGyroJerkMag-meanFreq()', -0.1091332157250801),
#  ('fBodyAcc-skewness()-Y', -0.11172203397725214),
#  ('tBodyGyro-mean()-Z', -0.12290215054377816),
#  ('tBodyGyroJerk-correlation()-X,Z', -0.13164611087204145),
#  ('tGravityAcc-arCoeff()-Y,3', -0.14473974368696005),
#  ('fBodyAccMag-skewness()', -0.1495442838893007),
#  ('tGravityAcc-sma()', -0.15615227939904416),
#  ('fBodyAccMag-meanFreq()', -0.1602108885480834),
#  ('tBodyGyroJerk-arCoeff()-X,3', -0.1700983985115927),
#  ('tBodyGyro-arCoeff()-X,3', -0.17504719506794222),
#  ('tBodyGyroJerk-arCoeff()-Y,3', -0.17592573567885592),
#  ('tBodyAcc-arCoeff()-Y,3', -0.17935951002080688),
#  ('fBodyAcc-kurtosis()-Y', -0.1808459940288106),
#  ('tBodyAccJerk-arCoeff()-Y,4', -0.18621815026633998),
#  ('tBodyAccJerk-arCoeff()-Y,3', -0.18805578633978842),
#  ('tGravityAcc-arCoeff()-Z,3', -0.19402425789491898),
#  ('fBodyAccMag-kurtosis()', -0.20586970739422514),
#  ('tBodyGyro-arCoeff()-Y,3', -0.20824669972903412),
#  ('fBodyBodyGyroMag-skewness()', -0.2114788462020147),
#  ('tBodyGyroJerk-arCoeff()-Z,4', -0.21205832713042302),
#  ('tBodyGyro-arCoeff()-X,4', -0.21431586686572854),
#  ('tBodyGyro-correlation()-X,Z', -0.22357833669958727),
#  ('fBodyBodyGyroMag-kurtosis()', -0.23424868018962366),
#  ('tBodyAccJerk-correlation()-X,Z', -0.23963210064467005),
#  ('tBodyAcc-arCoeff()-Z,3', -0.26848146901909187),
#  ('tBodyAccJerk-arCoeff()-Z,4', -0.27965350809185097),
#  ('tBodyGyroJerkMag-arCoeff()1', -0.28186861283254927),
#  ('fBodyGyro-meanFreq()-X', -0.2821377733241973),
#  ('fBodyAccJerk-maxInds-Y', -0.2844845167094014),
#  ('tBodyAccJerk-arCoeff()-Z,3', -0.28503694884168224),
#  ('tBodyAccJerk-arCoeff()-X,4', -0.28983208449804615),
#  ('tGravityAcc-arCoeff()-X,3', -0.29113961992364235),
#  ('tBodyAcc-arCoeff()-X,3', -0.3013733177192416),
#  ('fBodyAcc-meanFreq()-Y', -0.33492607294412186),
#  ('tBodyGyro-arCoeff()-Y,1', -0.3409219055563811),
#  ('tBodyAccJerk-correlation()-X,Y', -0.3432272908475844),
#  ('tBodyAccMag-arCoeff()3', -0.3571930531764949),
#  ('tGravityAccMag-arCoeff()3', -0.3571930531764949),
#  ('tBodyAccJerk-arCoeff()-X,3', -0.3683653086141758),
#  ('tBodyGyroJerk-arCoeff()-Z,3', -0.368736502722107),
#  ('fBodyGyro-meanFreq()-Z', -0.3690479314358152),
#  ('fBodyBodyAccJerkMag-meanFreq()', -0.3736092224673918),
#  ('fBodyAccJerk-maxInds-Z', -0.3765823519735896),
#  ('fBodyAcc-meanFreq()-X', -0.3766079840977712),
#  ('fBodyAcc-meanFreq()-Z', -0.38328693203031894),
#  ('tBodyGyroJerk-arCoeff()-Y,1', -0.3944335927065954),
#  ('tBodyAcc-correlation()-X,Y', -0.3996676797680554),
#  ('tGravityAcc-entropy()-Y', -0.4155020600653251),
#  ('tBodyGyro-arCoeff()-Z,3', -0.4943236942780466),
#  ('tBodyGyroJerk-arCoeff()-X,1', -0.5088796114531539),
#  ('tBodyAccMag-arCoeff()1', -0.5257311129329392),
#  ('tGravityAccMag-arCoeff()1', -0.5257311129329392),
#  ('tGravityAcc-energy()-Z', -0.5277719743492962),
#  ('tGravityAcc-energy()-Y', -0.5317926204912705),
#  ('fBodyAccJerk-maxInds-X', -0.5450439028216665),
#  ('tBodyGyro-arCoeff()-X,1', -0.5535144061134459),
#  ('tBodyAccJerkMag-arCoeff()1', -0.5758114358251667),
#  ('tBodyAcc-arCoeff()-Z,1', -0.5919822420499188),
#  ('tBodyGyroJerk-min()-Y', -0.5969150213652747),
#  ('tBodyAcc-arCoeff()-Y,1', -0.5988498338877961),
#  ('tBodyAcc-arCoeff()-X,1', -0.6044590579533411),
#  ('tBodyAccJerk-arCoeff()-Z,1', -0.6048353006299798),
#  ('tBodyAccJerk-arCoeff()-Y,1', -0.6059876095441126),
#  ('fBodyAccJerk-meanFreq()-Y', -0.6105624468064017),
#  ('tGravityAcc-max()-Z', -0.6177067947699354),
#  ('angle(X,gravityMean)', -0.6185037863569781),
#  ('fBodyAccJerk-meanFreq()-Z', -0.6185742450553013),
#  ('tGravityAcc-mean()-Z', -0.625985270355758),
#  ('tGravityAcc-min()-Z', -0.631560487178793),
#  ('tBodyGyro-arCoeff()-Z,1', -0.642150333081881),
#  ('tBodyAccJerk-arCoeff()-X,1', -0.6481268344234176),
#  ('tBodyGyroJerk-arCoeff()-Z,1', -0.6569760131883433),
#  ('fBodyAccJerk-meanFreq()-X', -0.6714808657256787),
#  ('tBodyAccJerk-min()-Z', -0.6769261286999748),
#  ('tBodyGyroJerk-min()-Z', -0.6848010193147239),
#  ('tBodyGyroJerk-min()-X', -0.6856907553537811),
#  ('tBodyGyro-min()-X', -0.6939528448752084),
#  ('tBodyGyro-min()-Y', -0.7057270966121832),
#  ('tBodyAccJerk-min()-Y', -0.7285941407646821),
#  ('tBodyAcc-min()-Z', -0.7312926123895097),
#  ('tGravityAcc-max()-Y', -0.7429208490342807),
#  ('tGravityAcc-mean()-Y', -0.7483984844203246),
#  ('tGravityAcc-min()-Y', -0.7494144124756885),
#  ('tBodyGyro-min()-Z', -0.7766842232944207),
#  ('tBodyAccJerk-min()-X', -0.778825981632235),
#  ('tBodyAcc-min()-Y', -0.7814075371050309),
#  ('tBodyAcc-min()-X', -0.8022590672939832)]

# %%
selected_columns = list(dict(cr[:100]).keys())[1:100]

# %%
X_1 = train[selected_columns]
y_1 = train['Activity']

# %%
X_1 = np.asanyarray(X_1)
y_1 = np.asanyarray(y_1)

# %%
from sklearn.model_selection import train_test_split
x_train , x_val , y_train , y_val = train_test_split(X_1 , y_1 , test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x_train)
x_train_s = sc.transform(x_train)
x_val_s = sc.transform(x_val)
# sc.fit(y_train)
# y_train_s = sc.transform(y_train)
# y_val_s = sc.transform(y_val)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir">مدل‌سازی</font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# اکنون می‌توانید با استفاده از الگوریتم‌های یادگیری ماشین، مدلی آموزش دهید که با گرفتن مقادیر ویژگی‌های دریافتی از سنسورها، نوع فعالیت در حال انجام را پیش‌بینی کند.
# در این قسمت از شما می‌خواهیم از الگوریتم <b>Support Vector Machine (SVM)</b> استفاده کنید و ترکیب‌های مختلفی از هایپرپارامترهای مهم این الگوریتم (<code>C</code>، <code>kernel</code> و <code>gamma</code>) را آزمایش کنید تا بهترین مدل را برای پیش‌بینی فعالیت‌های انسانی انتخاب کنید. در این قسمت می‌توانید از کتابخانه‌ی <code>sklearn</code> استفاده کنید و برای جست‌وجوی هایپرپارامترها می‌توانید از روشی همچون Grid Search استفاده کنید. منطقی است که برای پیدا کردن بهترین ترکیب هایپرپارامتر نیاز به مجموعه‌ی اعتبارسنجی یا استفاده از روش‌هایی مانند Cross Validation دارید.
# </font>
# </p>

# %%
# To-Do (Modeling)
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
svm = SVC()
params = {'kernel' : ['linear', 'rbf' , 'sigmoid' ] , 'C' : [0.01 , 0.1 , 1 , 10] , 'gamma' : ['scale' , 'auto']}
search = GridSearchCV(estimator= svm , param_grid=params , cv=5)
search.fit(x_train_s , y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'sigmoid']})

# %%
print(search.best_params_)
# Out:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
best_model = SVC(C= 10 ,gamma = 'scale' , kernel = 'rbf' )
best_model.fit(x_train_s,y_train)
y_train_pred = best_model.predict(x_train_s)
y_val_pred = best_model.predict(x_val_s)

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# با توجه به نتایجی که بر روی هر ترکیب هایپرپارامتر به دست آورده‌اید،‌ تاثیر هر یک از هایپرپارامترها را بر روی عملکرد مدل چه می‌دانید؟ دلایل و تحلیل خود را در سلول زیر بنویسید:
# <span style="color:red">(ضروری)</span>
# </font>
# </p>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: center;line-height:200%;font-family:vazir;font-size:medium;color:#0099cc"><font face="vazir" size=3><i>
# پارامتر C و همین طور kernel بسیار موثر هستند . به این دلیل که اولی ، تاثیر نادیده گرفتن پیش بینی های غلط را تعیین میکند و دومی ، نحوه انجام الگوریتم مورد نظر را تغییر میدهد.
# </i></font></p>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# حال نتایج مدل نهایی انتخاب‌شده را هم بر روی مجموعه‌ی آموزشی و هم اعتبارسنجی گزارش کنید. برای ارزیابی از معیارهای Accuracy، Precision، Recall و F1-Score استفاده کنید. همچنین ماتریس درهم‌ریختگی (Confusion Matrix) را رسم نمایید.
# </font>
# </p>

# %%
# To-Do (Evaluation)
from sklearn.metrics import r2_score,f1_score , recall_score , precision_score , confusion_matrix
# evaluation on train data
r2_train = r2_score(y_true = y_train , y_pred = y_train_pred)
f1_train = f1_score(y_true = y_train , y_pred = y_train_pred , average='weighted')
recall_train = recall_score(y_true = y_train , y_pred = y_train_pred , average='weighted')
prec_train = precision_score(y_true = y_train , y_pred = y_train_pred , average='weighted')
# evaluation on validation data
r2_val = r2_score(y_true = y_val , y_pred = y_val_pred)
f1_val = f1_score(y_true = y_val , y_pred = y_val_pred , average='weighted')
recall_val = recall_score(y_true = y_val , y_pred = y_val_pred , average='weighted')
prec_val = precision_score(y_true = y_val , y_pred = y_val_pred , average='weighted')
print(f"for train data : \nr2 score : {r2_train}\nf1 : {f1_train}\nrecall : {recall_train}\nprecision : {prec_train}")
print(f"confusion matrix : \n{confusion_matrix(y_true = y_train , y_pred = y_train_pred)}\n\n\n")
print(f"for validation data : \nr2 score : {r2_val}\nf1 : {f1_val}\nrecall : {recall_val}\nprecision : {prec_val}")
print(f"confusion matrix : \n{confusion_matrix(y_true = y_val , y_pred = y_val_pred)}")
# Out:
# for train data :
# r2 score : 0.9165917420469128
# f1 : 0.8835325632562292
# recall : 0.8834045860862806
# precision : 0.8841209902781053
# confusion matrix :
# [[807  87 122   0   0   0]
#  [ 79 706 118   0   0   0]
#  [ 81 101 778   0   0   0]
#  [  0   0   0 845   0   1]
#  [  0   0   0   1 689   3]
#  [  0   0   0   5   2 721]]
#
#
#
# for validation data :
# r2 score : 0.9164967978722852
# f1 : 0.8802450249595757
# recall : 0.8803263825929284
# precision : 0.8804071521697195
# confusion matrix :
# [[320  38  33   0   0   0]
#  [ 41 293  49   0   0   0]
#  [ 48  45 321   0   0   0]
#  [  0   0   0 379   0   1]
#  [  0   0   0   1 290   2]
#  [  0   0   0   5   1 339]]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir">پیش‌بینی برای مجموعه‌ی آزمون</font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# اکنون از مدلی که آموزش داده‌اید برای پیش‌بینی نمونه‌های مجموعه‌ی آزمون استفاده کرده تا متوجه شوید که مدل شما تا چه میزان برای نمونه‌های جدید و مشاهده‌نشده موفق عمل می‌کند. نیاز است پیش‌بینی‌های مدل خود را در یک دیتافریم با نام <code>submission</code> که شامل یک ستون به نام <code>Activity_Name</code> است ذخیره کنید. ردیف اول از این دیتافریم، پیش‌بینی مدل شما برای نمونه‌ی نخست و ردیف آخر از آن،‌ پیش‌بینی مدل شما برای نمونه‌ی آخر مجموعه‌ی آزمون است. توجه داشته باشید که مقادیر این ستون باید از جنس دسته‌ای و مشابه با مقادیر آن در مجموعه‌ی آموزشی باشد. یک نمونه‌ی فرضی از دیتافریم شما در جدول زیر نشان داده شده است:
# </font>
# </p>
#
# <center>
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# | <code>Activity_Name</code> |
# | :---: |
# | Walking |
# | Sitting |
# | Sitting |
# | Walking_Upstairs |
# | ... |
#
# </font>
# </p>
# </center>

# %%
x_test = test[selected_columns]
x_test = np.asanyarray(x_test)
x_test_s = sc.transform(x_test)

# %%
submission = pd.DataFrame({'Activity_Name' : le.inverse_transform(best_model.predict(x_test_s))})
submission.head()
# Out:
#   Activity_Name
# 0      Standing
# 1       Walking
# 2      Standing
# 3       Walking
# 4        Laying

# %%
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir">ارزیابی</font>
# </h2>
#
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# معیاری که برای ارزیابی مدل شما استفاده خواهد شد <code>F1-score</code> نام دارد و آرگومان میانگین‌گیری آن معادل حالت وزن‌دار (<code dir=ltr>average='weighted'</code>) تنظیم خواهد شد. جهت مطالعه‌ی مستندات این کلاس می‌توانید به <a href="https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html" target="_blank">این لینک</a> مراجعه فرمایید.
# </font>
# </p>
#
#
# $$F_1=\frac{tp}{tp+\frac{1}{2}(fp+fn)}$$
#
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# <span style="color:red"><b>توجه:</b></span>
# جهت کسب امتیاز کامل نیاز است پاسخ شما حداقل مقدار(درصد) <code>96</code> را با توجه به این معیار کسب کند.
# <br>
# <span style="color:orange"><b>نکته:</b></span>
# برای پاسخ‌هایی که عملکردی کمتر از این حد آستانه کسب کنند، امتیاز <code>0</code> منظور می‌شود و برای عملکردهایی بهتر از این حد آستانه،‌ به همان میزان، نمره‌ی اضافه برای این بخش در نظر گرفته خواهد شد.
# <br>
# <span style="color:orange"><b>نکته:</b></span>
# از ذخیره بودن نت‌بوک خود در ارسال نهایی اطمینان حاصل کنید زیرا که نت‌بوک شما نیز مورد داوری دستی قرار خواهد گرفت و نمره‌ی نهایی شما از ترکیب نمره‌ی پیش‌بینی مدل و نمره‌ی داوری دستی (راه‌حل و تحلیل) محاسبه خواهد شد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

submission.to_csv('submission.csv', index=False)
file_names = ['human_activity_classification.ipynb', 'submission.csv']
compress(file_names)
